# %%
import re

def convert_to_dicts(block):
    # Regular expression pattern
    pattern = r'<(.*?)>(.*?)</\1>'
    
    # Find all matches in the block
    matches = re.findall(pattern, block, re.DOTALL)

    result = []
    current_speaker = None
    current_line = ""

    for speaker, line in matches:
        line = line.strip().replace('\n', ' ').replace('"', '')
        
        if speaker == current_speaker and len(current_line) + len(line) <= 200:
            current_line += " " + line
        else:
            if current_speaker is not None:
                result.append({'speaker': current_speaker, 'line': current_line.strip()})
            current_speaker = speaker
            current_line = line

    # Add the last speaker's lines to the result
    if current_speaker is not None:
        result.append({'speaker': current_speaker, 'line': current_line.strip()})

    return result



# Input block
block = """
<garnt> - I like that, I like the aesthetic. </garnt>
<connor> - Yeah, I like that too.
- Yeah, yeah. </connor>
<connor> - I think it's just cool. </connor>
<connor> - I think the problem is </connor>
<connor> that it's a lot of times,
it's just kind of like, </connor>
<connor> oh, cool, you're wearing a scarf with your shirt, </connor>
<connor> and it's like, oh, cool, </connor>
<connor> I'm gonna wear a scarf
with my shirt now as well. </connor>
<connor> - Yeah, yeah, exactly. </connor>
<connor> - It's just, it's like, </connor>
<connor> it's just like, yeah, yeah,
I'm gonna do that as well. </connor>
<connor> - And then you end up having </connor>
<connor> like three scarves on your neck, </connor>
<connor> and you look like a complete idiot, </connor>
<joey> 'cause no one would ever wear three scarves. </joey>
<connor> - I don't know, if I was
a rich person, I'd probably wear, </connor>
<connor> I'd probably wear like three scarves. </connor>
<connor> - I'd probably just wear one
scarf that was like, </connor>
<joey> really long and like,
you know, just like, </joey>
<joey> just like have that one scarf
that was like, oh, </joey>
<joey> it's like just like, you know, </joey>
<joey> you're just like, oh,
I'm just gonna wear this. </joey>
<connor> I'm just gonna wear it
until it gets old, </connor>
<connor> and then I'll probably
just have a scarf burning ceremony. </connor>
<connor> - I don't, I just don't know. </connor>
<connor> - I don't know. </connor>
<connor> I don't know.
- I don't know. </connor>
<joey> I think that's the only
reason why I don't wear one, </joey>
<connor> I think it's just like, </connor>
<connor> I don't know how to wear it right. </connor>
<connor> - I know how to wear it
right, I know I know how to wear it, </connor>
<connor> but I know that if I wear
a scarf, I'll end up with, </connor>
<connor> I'll end up looking like a fucking idiot, </connor>
<joey> so I don't want to risk it. </joey>
<joey> - So we didn't, so
we didn't have a scarf, </joey>
"""

result = convert_to_dicts(block)
result
# Out:
# [{'speaker': 'garnt', 'line': '- I like that, I like the aesthetic.'},
#  {'speaker': 'connor',
#   'line': "- Yeah, I like that too. - Yeah, yeah. - I think it's just cool. - I think the problem is that it's a lot of times, it's just kind of like, oh, cool, you're wearing a scarf with your shirt,"},
#  {'speaker': 'connor',
#   'line': "and it's like, oh, cool, I'm gonna wear a scarf with my shirt now as well. - Yeah, yeah, exactly. - It's just, it's like, it's just like, yeah, yeah, I'm gonna do that as well."},
#  {'speaker': 'connor',
#   'line': '- And then you end up having like three scarves on your neck, and you look like a complete idiot,'},
#  {'speaker': 'joey', 'line': "'cause no one would ever wear three scarves."},
#  {'speaker': 'connor',
#   'line': "- I don't know, if I was a rich person, I'd probably wear, I'd probably wear like three scarves. - I'd probably just wear one scarf that was like,"},
#  {'speaker': 'joey',
#   'line': "really long and like, you know, just like, just like have that one scarf that was like, oh, it's like just like, you know, you're just like, oh, I'm just gonna wear this."},
#  {'speaker': 'connor',
#   'line': "I'm just gonna wear it until it gets old, and then I'll probably just have a scarf burning ceremony. - I don't, I just don't know. - I don't know. I don't know. - I don't know."},
#  {'speaker': 'joey',
#   'line': "I think that's the only reason why I don't wear one,"},
#  {'speaker': 'connor',
#   'line': "I think it's just like, I don't know how to wear it right. - I know how to wear it right, I know I know how to wear it, but I know that if I wear a scarf, I'll end up with,"},
#  {'speaker': 'connor', 'line': "I'll end up looking like a fucking idiot,"},
#  {'speaker': 'joey',
#   'line': "so I don't want to risk it. - So we didn't, so we didn't have a scarf,"}]

# %%
for i, l in enumerate(result):
    speaker = l['speaker']
    line = l['line']
    to_run = f'python ../../../tortoise-tts/tortoise/do_tts.py --text "{line}" --voice "{speaker}" --output_path "results/llama/llama_{i}/" --preset "fast"'
    # print(len(to_run))
    print(to_run)
# Out:
# python ../../../tortoise-tts/tortoise/do_tts.py --text "- I like that, I like the aesthetic." --voice "garnt" --output_path "results/llama/llama_0/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "- Yeah, I like that too. - Yeah, yeah. - I think it's just cool. - I think the problem is that it's a lot of times, it's just kind of like, oh, cool, you're wearing a scarf with your shirt," --voice "connor" --output_path "results/llama/llama_1/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "and it's like, oh, cool, I'm gonna wear a scarf with my shirt now as well. - Yeah, yeah, exactly. - It's just, it's like, it's just like, yeah, yeah, I'm gonna do that as well." --voice "connor" --output_path "results/llama/llama_2/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "- And then you end up having like three scarves on your neck, and you look like a complete idiot," --voice "connor" --output_path "results/llama/llama_3/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "'cause no one would ever wear three scarves." --voice "joey" --output_path "results/llama/llama_4/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "- I don't know, if I was a rich person, I'd probably wear, I'd probably wear like three scarves. - I'd probably just wear one scarf that was like," --voice "connor" --output_path "results/llama/llama_5/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "really long and like, you know, just like, just like have that one scarf that was like, oh, it's like just like, you know, you're just like, oh, I'm just gonna wear this." --voice "joey" --output_path "results/llama/llama_6/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "I'm just gonna wear it until it gets old, and then I'll probably just have a scarf burning ceremony. - I don't, I just don't know. - I don't know. I don't know. - I don't know." --voice "connor" --output_path "results/llama/llama_7/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "I think that's the only reason why I don't wear one," --voice "joey" --output_path "results/llama/llama_8/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "I think it's just like, I don't know how to wear it right. - I know how to wear it right, I know I know how to wear it, but I know that if I wear a scarf, I'll end up with," --voice "connor" --output_path "results/llama/llama_9/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "I'll end up looking like a fucking idiot," --voice "connor" --output_path "results/llama/llama_10/" --preset "fast"
# python ../../../tortoise-tts/tortoise/do_tts.py --text "so I don't want to risk it. - So we didn't, so we didn't have a scarf," --voice "joey" --output_path "results/llama/llama_11/" --preset "fast"
